# %% [markdown]
# <a href="https://colab.research.google.com/github/azamjon98/final_project/blob/main/avia_company_satisfaction_rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
train_path = 'train_dataset.csv'
test_path = 'test_dataset.csv'

# %%
import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

import seaborn as sns

from scipy.stats import norm

import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OrdinalEncoder, StandardScaler
encoder=OrdinalEncoder()
scaler=StandardScaler()

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
from sklearn.metrics import roc_curve, roc_auc_score, auc, confusion_matrix, classification_report, accuracy_score, f1_score, precision_score, recall_score

# %%
train=pd.read_csv(train_path)
test=pd.read_csv(test_path)
train.shape, test.shape
# Out:
# ((10000, 24), (4000, 23))

# %%
train.head()
# Out:
#    id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   1    Male  disloyal Customer   33  Business travel       Eco
# 1   2  Female     Loyal Customer   49  Business travel  Business
# 2   3  Female     Loyal Customer   43  Business travel       Eco
# 3   4  Female     Loyal Customer   27  Business travel  Business
# 4   5    Male     Loyal Customer   11  Personal Travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              571                      2                                  3
# 1             1431                      4                                  1
# 2              867                      1                                  4
# 3             1550                      3                                  3
# 4              526                      3                                  4
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       2  ...                       4                 3
# 1                       4  ...                       5                 5
# 2                       4  ...                       1                 1
# 3                       3  ...                       2                 4
# 4                       3  ...                       4                 5
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 1                 3                4                 3
# 1                 5                 5                3                 5
# 2                 1                 1                1                 1
# 3                 4                 5                5                 4
# 4                 2                 5                3                 5
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            4                          10                       3.0
# 1            3                           0                       0.0
# 2            2                           0                      18.0
# 3            2                           0                       0.0
# 4            4                           0                      10.0
#
#    satisfaction
# 0             0
# 1             1
# 2             0
# 3             1
# 4             0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Exploratory data analysis

# %%
df=train.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 10000 non-null  int64
#  1   Gender                             10000 non-null  object
#  2   Customer Type                      10000 non-null  object
#  3   Age                                10000 non-null  int64
#  4   Type of Travel                     10000 non-null  object
#  5   Class                              10000 non-null  object
#  6   Flight Distance                    10000 non-null  int64
#  7   Inflight wifi service              10000 non-null  int64
#  8   Departure/Arrival time convenient  10000 non-null  int64
#  9   Ease of Online booking             10000 non-null  int64
#  10  Gate location                      10000 non-null  int64
#  11  Food and drink                     10000 non-null  int64
#  12  Online boarding                    10000 non-null  int64
#  13  Seat comfort                       10000 non-null  int64
#  14  Inflight entertainment             10000 non-null  int64
#  15  On-board service                   10000 non-null  int64
#  16  Leg room service                   10000 non-null  int64
#  17  Baggage handling                   10000 non-null  int64
#  18  Checkin service                    10000 non-null  int64
#  19  Inflight service                   10000 non-null  int64
#  20  Cleanliness                        10000 non-null  int64
#  21  Departure Delay in Minutes         10000 non-null  int64
#  22  Arrival Delay in Minutes           9972 non-null   float64
#  23  satisfaction                       10000 non-null  int64
# dtypes: float64(1), int64(19), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# #### Arrival Delay in Minutes columns has 28 nan values we will treat later

# %%
df.describe()
# Out:
#                 id           Age  Flight Distance  Inflight wifi service  \
# count  10000.00000  10000.000000     10000.000000           10000.000000
# mean    5000.50000     39.375100      1229.556200               2.780200
# std     2886.89568     14.897959      1022.281958               1.362745
# min        1.00000      7.000000        31.000000               0.000000
# 25%     2500.75000     27.000000       421.000000               2.000000
# 50%     5000.50000     40.000000       863.500000               3.000000
# 75%     7500.25000     51.000000      1806.750000               4.000000
# max    10000.00000     80.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                       10000.000000            10000.000000
# mean                            3.065100                2.797800
# std                             1.527316                1.421168
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding  Seat comfort  \
# count   10000.000000    10000.000000     10000.000000   10000.00000
# mean        2.981000        3.214500         3.349100       3.49140
# std         1.283278        1.333217         1.352779       1.31122
# min         1.000000        0.000000         0.000000       0.00000
# 25%         2.000000        2.000000         2.000000       3.00000
# 50%         3.000000        3.000000         4.000000       4.00000
# 75%         4.000000        4.000000         4.000000       5.00000
# max         5.000000        5.000000         5.000000       5.00000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count            10000.000000      10000.000000      10000.000000
# mean                 3.402900          3.454100          3.415700
# std                  1.331822          1.274777          1.308765
# min                  0.000000          1.000000          0.000000
# 25%                  2.000000          3.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  5.000000          4.000000          5.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service   Cleanliness  \
# count      10000.000000     10000.000000      10000.000000  10000.000000
# mean           3.676200         3.360600          3.680100      3.311100
# std            1.189746         1.258462          1.175118      1.311217
# min            1.000000         0.000000          1.000000      0.000000
# 25%            3.000000         3.000000          3.000000      2.000000
# 50%            4.000000         3.000000          4.000000      3.000000
# 75%            5.000000         4.000000          5.000000      4.000000
# max            5.000000         5.000000          5.000000      5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes  satisfaction
# count                10000.000000               9972.000000  10000.000000
# mean                    14.429900                 14.709888      0.500000
# std                     39.659674                 40.046355      0.500025
# min                      0.000000                  0.000000      0.000000
# 25%                      0.000000                  0.000000      0.000000
# 50%                      0.000000                  0.000000      0.500000
# 75%                     12.000000                 12.000000      1.000000
# max                    921.000000                924.000000      1.000000

# %% [markdown]
# #### we do not need id sp we will drop it

# %%
df=df.drop('id',axis=1)

# %%
# let's count all unique values oin each column
cols=df.columns
for i in range(len(cols)):
    print('column name: ',cols[i])
    print('all unique values: ',df[cols[i]].unique())
    print('total number of unique values: ',df[cols[i]].nunique())
    print('-'*60)
# Out:
# column name:  Gender
# all unique values:  ['Male' 'Female']
# total number of unique values:  2
# ------------------------------------------------------------
# column name:  Customer Type
# all unique values:  ['disloyal Customer' 'Loyal Customer']
# total number of unique values:  2
# ------------------------------------------------------------
# column name:  Age
# all unique values:  [33 49 43 27 11 30 38 39 24 62 42 59 19 56 46 47 31 36 29 52 34 44 45 58
#  41 69 67 68 25 54 40 55 60 26 15 61 20 64 57 53 13 50 48 51 17 23 72 80
#  28  8 37  9 21 32 65 12 22 35 18 10 16 63  7 70 66 77 79 73 14 71 76 74
#  75 78]
# total number of unique values:  74
# ------------------------------------------------------------
# column name:  Type of Travel
# all unique values:  ['Business travel' 'Personal Travel']
# total number of unique values:  2
# ------------------------------------------------------------
# column name:  Class
# all unique values:  ['Eco' 'Business' 'Eco Plus']
# total number of unique values:  3
# ------------------------------------------------------------
# column name:  Flight Distance
# all unique values:  [ 571 1431  867 ... 2653 1223 1631]
# total number of unique values:  2421
# ------------------------------------------------------------
# column name:  Inflight wifi service
# all unique values:  [2 4 1 3 5 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Departure/Arrival time convenient
# all unique values:  [3 1 4 2 5 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Ease of Online booking
# all unique values:  [2 4 3 1 5 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Gate location
# all unique values:  [4 3 2 1 5]
# total number of unique values:  5
# ------------------------------------------------------------
# column name:  Food and drink
# all unique values:  [4 3 2 5 1 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Online boarding
# all unique values:  [2 5 4 3 0 1]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Seat comfort
# all unique values:  [4 3 2 5 1 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Inflight entertainment
# all unique values:  [4 5 1 2 3 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  On-board service
# all unique values:  [3 5 1 4 2]
# total number of unique values:  5
# ------------------------------------------------------------
# column name:  Leg room service
# all unique values:  [1 5 4 2 3 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Baggage handling
# all unique values:  [3 5 1 4 2]
# total number of unique values:  5
# ------------------------------------------------------------
# column name:  Checkin service
# all unique values:  [4 3 1 5 2 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Inflight service
# all unique values:  [3 5 1 4 2]
# total number of unique values:  5
# ------------------------------------------------------------
# column name:  Cleanliness
# all unique values:  [4 3 2 5 1 0]
# total number of unique values:  6
# ------------------------------------------------------------
# column name:  Departure Delay in Minutes
# all unique values:  [ 10   0   2  62   1  76  16  12  42  36   5  31   3   7  17 138  37   4
#   15  11  28  57  35 269  14  27  47  21 208  20  68  56  32   8  75  25
#   61   6  29 175 127 307  30  13  43  81  63  33  19  89  72  23   9  85
#  100  38  59  34 243 188 133 110  24  49 131  93 102 252 101 126  55 289
#   26  18  64  95  71  46 156  22  84 501  58  48 106  51 147 227  41  92
#   53  50  39  69  45 264  90  44 117  40 108  82  66  52 112 182 141 338
#   67 116 180  79  74 120 235 105  77  94 207  65 294 176  98 172 178 194
#  200 199 146  78 123  54 158  87 148 142 260 144 149  60 233 124  73 140
#  230 202 109 107 129 114 118 181 726 174 104  80 113 163 153 185 103 205
#  197  70 241 151  83 137 152  86 277 177  97 318  88 228 136 531 125 130
#   91 210 211 196 164 186 218 139 724 134 245 150  96 119 135 302 921 170
#   99 169 115 157 248 183 454 121 173 160 258 224 171 195 192 423 193 143
#  161 145 273 154 166 250 729 288 184 427 519 209 212 465 480 225 179 132
#  167 165 394 271 429]
# total number of unique values:  239
# ------------------------------------------------------------
# column name:  Arrival Delay in Minutes
# all unique values:  [  3.   0.  18.  10.   5.  17.  60.  61.   2.  32.   1.  51.  14.  16.
#   21. 134.   7.  28.   8.   4.  26. 105.  50. 260.   6.  22.  47.   9.
#  204.  25.  41.  48.  20.  12.  31.  72.  23.  33.  64.  13.  nan 131.
#  299.  38.  34.  71.  73. 109.  87.  29.  46. 226. 199. 118. 148.  56.
#   40.  19. 129.  11.  27. 121.  44.  83.  15.  97. 235.  92.  35.  70.
#  279.  39.  85.  43. 167. 111.  63. 500.  49. 155.  84. 208.  37.  53.
#   67.  90.  55.  24.  30.  65.  99.  78.  52.  54. 256.  89.  94.  36.
#   58. 107.  76.  57.  88. 247. 120.  69. 139. 123.  62. 334.  86. 174.
#  115.  93. 222.  59. 103.  74.  68. 288. 175.  96. 168. 183.  77. 190.
#   42.  81. 188.  45. 159. 122. 152. 217. 135. 104.  79.  95. 100. 158.
#  186. 153. 113. 138. 146. 228. 127. 133. 232. 185. 191. 150. 108. 144.
#   98. 110. 106. 114.  66. 160.  75.  82. 691. 162. 198. 147.  80. 267.
#  170. 102. 261. 164. 116. 157. 101. 278. 163. 301. 219. 485. 119. 112.
#  172. 124. 132. 141. 161. 211. 136. 233. 189. 137. 171. 165. 705.  91.
#  254. 140. 284. 125. 314. 924. 149. 128. 231. 142. 145. 117. 268. 178.
#  502. 262. 216. 169. 403. 143. 193. 259. 227. 253. 205. 717. 277. 130.
#  173. 385. 440. 283. 250. 516. 493. 471. 223. 126. 181. 195. 166. 242.
#  179. 417. 407. 270. 210.]
# total number of unique values:  242
# ------------------------------------------------------------
# column name:  satisfaction
# all unique values:  [0 1]
# total number of unique values:  2
# ------------------------------------------------------------

# %% [markdown]
# #### treating nan values

# %%
df['Arrival Delay in Minutes'].isna().sum()
# Out:
# np.int64(28)

# %%
df['Arrival Delay in Minutes'].unique()
# Out:
# array([  3.,   0.,  18.,  10.,   5.,  17.,  60.,  61.,   2.,  32.,   1.,
#         51.,  14.,  16.,  21., 134.,   7.,  28.,   8.,   4.,  26., 105.,
#         50., 260.,   6.,  22.,  47.,   9., 204.,  25.,  41.,  48.,  20.,
#         12.,  31.,  72.,  23.,  33.,  64.,  13.,  nan, 131., 299.,  38.,
#         34.,  71.,  73., 109.,  87.,  29.,  46., 226., 199., 118., 148.,
#         56.,  40.,  19., 129.,  11.,  27., 121.,  44.,  83.,  15.,  97.,
#        235.,  92.,  35.,  70., 279.,  39.,  85.,  43., 167., 111.,  63.,
#        500.,  49., 155.,  84., 208.,  37.,  53.,  67.,  90.,  55.,  24.,
#         30.,  65.,  99.,  78.,  52.,  54., 256.,  89.,  94.,  36.,  58.,
#        107.,  76.,  57.,  88., 247., 120.,  69., 139., 123.,  62., 334.,
#         86., 174., 115.,  93., 222.,  59., 103.,  74.,  68., 288., 175.,
#         96., 168., 183.,  77., 190.,  42.,  81., 188.,  45., 159., 122.,
#        152., 217., 135., 104.,  79.,  95., 100., 158., 186., 153., 113.,
#        138., 146., 228., 127., 133., 232., 185., 191., 150., 108., 144.,
#         98., 110., 106., 114.,  66., 160.,  75.,  82., 691., 162., 198.,
#        147.,  80., 267., 170., 102., 261., 164., 116., 157., 101., 278.,
#        163., 301., 219., 485., 119., 112., 172., 124., 132., 141., 161.,
#        211., 136., 233., 189., 137., 171., 165., 705.,  91., 254., 140.,
#        284., 125., 314., 924., 149., 128., 231., 142., 145., 117., 268.,
#        178., 502., 262., 216., 169., 403., 143., 193., 259., 227., 253.,
#        205., 717., 277., 130., 173., 385., 440., 283., 250., 516., 493.,
#        471., 223., 126., 181., 195., 166., 242., 179., 417., 407., 270.,
#        210.])

# %% [markdown]
# #### Let's see its distribution

# %%
x=df['Arrival Delay in Minutes'].sort_values()
mu = loc = x.mean()
sc = scale = x.std()
y=norm.pdf(x,mu ,sc)
plt.figure(figsize=(16,8))
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### It is very highly right skewed so we should apply ffill method

# %%
df['Arrival Delay in Minutes']=df['Arrival Delay in Minutes'].fillna(0)

# %%
df['Arrival Delay in Minutes'].isna().sum()

## now there is no any none values
# Out:
# np.int64(0)

# %%
x=df['Arrival Delay in Minutes'].sort_values()
y=norm.pdf(x,loc=x.mean(),scale=x.std())
plt.figure(figsize=(16,8))
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Data visualization

# %%
## satisfaction score by gender

sns.countplot(data=df,x='Gender',hue='satisfaction')
plt.show()

# %% [markdown]
# ### The ratio of satisfied and not satisfied clients according to gender is equal to each other, and we have a bit more female clients than males

# %%
### satisfaction score by 'Customer Type'
sns.countplot(data=df, x='Customer Type',hue='satisfaction')
plt.yticks(np.arange(0,5000,500))
plt.grid()
plt.show()

# %% [markdown]
# ### among loyal customers 45% of total are satisfied while 38 % of total have complaints, and figures for disloyal customers equal to 5% and 12% respectively.

# %%
## satisfaction score for the 'Age' column
sns.histplot(data=df,x='Age',hue='satisfaction',bins=60)
plt.show()

# %% [markdown]
# ### exept among 45-60 age group, among all other age groups,the number of dissatisfied clients exceeds those who are satisfied

# %%
### satisfaction rate on 'Type of Travel'
sns.countplot(data=df,x='Type of Travel', hue='satisfaction')
plt.show()

# %% [markdown]
# ### From above number of dissatisfied clients are equal on both cases. However clients have more copliances if they fly on personal reasons

# %%
# satisfacion score on 'Class'
sns.countplot(data=df, x='Class',hue='satisfaction')
plt.show()

# %% [markdown]
# ### Except business class users, there are much more dissatisfied clients than those who are satisfied

# %%
### Inflight wifi service
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='Inflight wifi service',hue='satisfaction' )
plt.show()

# %% [markdown]
# #### here we can see that Inflight wifi service can also have some causes on dissatisfaction rate, if its score is 4 or 5, there are much more satisfied clients

# %%
## Departure/Arrival time convenient
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='Departure/Arrival time convenient',hue='satisfaction' )
plt.show()

# %% [markdown]
# ### There is a litlle association between satisfaction score and Departure/Arrival time convenient

# %%
# Ease of Online booking
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='Ease of Online booking',hue='satisfaction' )
plt.show()

# %% [markdown]
# #### here we can see that Ease of Online Booking can also have some causes on dissatisfaction rate, if its score is 4 or 5, there are much more satisfied clients

# %%
cols=['Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']
## satisfaction score for other columns
for i in range(len(cols)):
    plt.figure(figsize=(10,5))
    sns.countplot(data=df,x=cols[i],hue='satisfaction')
    plt.title(f"Satisfaction score on {cols[i]}")
    plt.show()

# %% [markdown]
# #### on above we can conclude that  if score is 4 or 5 they will satisfy

# %%
col=['Flight Distance','Departure Delay in Minutes', 'Arrival Delay in Minutes']
for i in range(len(col)):
    plt.figure(figsize=(15,8))
    sns.histplot(data=df,x=col[i],hue='satisfaction',bins=60)
    plt.title(col[i])
    plt.xticks(np.arange(0,df[col[i]].max(),np.round(df[col[i]].max()/20)))
    plt.show()

# %% [markdown]
# ### It is easy to see that more than 15 minutes delays can cause compliances, and interestingly, there are much more satisfied clients those who travelled more than 1300 units. And all data is highly right skewed

# %% [markdown]
# # Preprocessing

# %%
def preprocessing1(df):
    df=df.drop('id',axis=1)
    df=df.fillna(method='ffill')
    cols=['Gender', 'Customer Type','Type of Travel', 'Class']
    df[cols]=encoder.fit_transform(df[cols])
    if 'satisfaction' in df.columns:
        y=df['satisfaction']
        df=df.drop(columns='satisfaction')
    else:
        y=None
    X=df.copy()
    return X,y

# %%
x,y=preprocessing1(train)

# %% [markdown]
# ### Feature selection:

# %% [markdown]
# | Method                        | Feature Type           | Target Type           | Use Case                                                   |
# |-------------------------------|------------------------|-----------------------|------------------------------------------------------------|
# | Chi-Square Test               | Categorical            | Categorical           | Classification with categorical features and target       |
# | F-Test (ANOVA F-value)       | Continuous             | Categorical           | Classification with continuous features and categorical target |

# %%
from sklearn.feature_selection import chi2,SelectKBest,f_classif

# %%
col1=['Flight Distance','Departure Delay in Minutes', 'Arrival Delay in Minutes']
x_f=x[col1].copy()
x_chi=x.drop(col1,axis=1)

# %%
f_scores = f_classif(x_f, y)
anova_p=pd.Series(f_scores[1], index=x_f.columns, name="anova_p_values")
anova_p.sort_values()
# Out:
# Flight Distance               3.357609e-205
# Arrival Delay in Minutes       1.498066e-06
# Departure Delay in Minutes     1.727657e-05
# Name: anova_p_values, dtype: float64

# %% [markdown]
# ### We should take all features because p_val_<0.05

# %%
chi2_scores=chi2(x_chi,y)
chi2_p=pd.Series(chi2_scores[1], index=x_chi.columns, name="chi2 p_values")
chi2_p.sort_values()
# Out:
# Type of Travel                        0.000000e+00
# Class                                 0.000000e+00
# Online boarding                      6.043256e-305
# Age                                  3.270546e-257
# Inflight entertainment               3.492407e-184
# Seat comfort                         1.765197e-127
# Leg room service                     9.567082e-117
# Inflight wifi service                8.835702e-114
# On-board service                     5.063543e-111
# Cleanliness                          9.325755e-111
# Customer Type                         1.580250e-61
# Checkin service                       2.835148e-57
# Food and drink                        6.939637e-54
# Baggage handling                      2.035774e-53
# Inflight service                      3.754491e-49
# Ease of Online booking                1.802419e-44
# Departure/Arrival time convenient     3.627246e-09
# Gate location                         5.941358e-01
# Gender                                8.516325e-01
# Name: chi2 p_values, dtype: float64

# %% [markdown]
# ### We should drop Gate location and Gender columns because p_val>0.05

# %%
def preprocessing(df):
    df=df.drop('id',axis=1)
    df=df.fillna(method='ffill')
    cols=['Gender', 'Customer Type','Type of Travel', 'Class']
    df[cols]=encoder.fit_transform(df[cols])
    if 'satisfaction' in df.columns:
        y=df['satisfaction']
        df=df.drop(columns='satisfaction')
    else:
        y=None
    X=df.copy()
    X=X.drop(columns=['Gate location','Gender'])
    X[X.columns]=scaler.fit_transform(X[X.columns])
    return X,y

# %%
x,y=preprocessing(train)

# %%
trainx,testx,trainy,testy=train_test_split(x,y,test_size=0.2,random_state=32)

# %%
model=lr.fit(trainx,trainy)
pred=model.predict(testx)
print('roc_auc_score',roc_auc_score(testy,pred))
# Out:
# roc_auc_score 0.8611717896707755

# %%
model=dt.fit(trainx,trainy)
pred=model.predict(testx)
print('roc_auc_score',roc_auc_score(testy,pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 model=dt.fit(trainx,trainy)
#       2 pred=model.predict(testx)
#       3 print('roc_auc_score',roc_auc_score(testy,pred))
#
# NameError: name 'dt' is not defined

# %%
model=rf.fit(trainx,trainy)
pred=model.predict(testx)
print('roc_auc_score',roc_auc_score(testy,pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 model=rf.fit(trainx,trainy)
#       2 pred=model.predict(testx)
#       3 print('roc_auc_score',roc_auc_score(testy,pred))
#
# NameError: name 'rf' is not defined

# %%
knn=KNeighborsClassifier(n_neighbors=5)
model=knn.fit(trainx,trainy)
pred=model.predict(testx)
print('roc_auc_score',roc_auc_score(testy,pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 knn=KNeighborsClassifier(n_neighbors=5)
#       2 model=knn.fit(trainx,trainy)
#       3 pred=model.predict(testx)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
model=svc.fit(trainx,trainy)
pred=model.predict(testx)
print('roc_auc_score',roc_auc_score(testy,pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 model=svc.fit(trainx,trainy)
#       2 pred=model.predict(testx)
#       3 print('roc_auc_score',roc_auc_score(testy,pred))
#
# NameError: name 'svc' is not defined

# %%
model=xgb.fit(trainx,trainy)
pred=model.predict(testx)
print('roc_auc_score',roc_auc_score(testy,pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 model=xgb.fit(trainx,trainy)
#       2 pred=model.predict(testx)
#       3 print('roc_auc_score',roc_auc_score(testy,pred))
#
# NameError: name 'xgb' is not defined

# %%
test_data,y=preprocessing(test)
x,y=preprocessing(train)
test_data.shape,x.shape
# Out:
# ((4000, 20), (10000, 20))

# %%
model=xgb.fit(x,y)
pred=model.predict(test_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 model=xgb.fit(x,y)
#       2 pred=model.predict(test_data)
#
# NameError: name 'xgb' is not defined

# %%
model1=rf.fit(x,y)
pred1=model1.predict(test_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 model1=rf.fit(x,y)
#       2 pred1=model1.predict(test_data)
#
# NameError: name 'rf' is not defined
